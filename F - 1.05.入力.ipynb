# %%
a, b, c = input().split()

print(a)
print(b)
print(c)
# Out:
# 10 20 30
# 10
# 20
# 30

# %%
string = input("文字列を入力してください:")
print("文字列", string, "が入力されました。")
# Out:
# 文字列を入力してください:Hello
# 文字列 Hello が入力されました。

# %%
a, b, c = input().split()
a = int(a)
b = int(b)
c = int(c)

print(a * 10)
print(b * 100)
print(c * 1000)
# Out:
# 10 20 30
# 100
# 2000
# 30000

# %%
a, b, c = input().split(":")

print(a)
print(b)
print(c)
# Out:
# 10:20:30
# 10
# 20
# 30

# %%
A,B = map(int, input(), split())
print(A+B)
# Out:
# 1 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fcea5eb8cf2d> in <cell line: 1>()
# ----> 1 A,B = map(int, input(), split())
#       2 print(A+B)
#
# NameError: name 'split' is not defined

# %%
A,B = map(int, input().split())
print(A+B)
# Out:
# 10 11
# 21
